# %%
from ultralytics import YOLO
#1.deney:YOLO8
model = YOLO("yolov8n.pt")

model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,    
    lr0=0.001,      
    optimizer="SGD"   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.240 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.12.3 torch-2.9.1+cpu CPU (11th Gen Intel Core i7-11800H @ 2.30GHz)
# ...

# %%
from ultralytics import YOLO

# 2. Deney:YOLO11
model = YOLO("yolo11n.pt") 

model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    optimizer="SGD",
    name="yolo11"
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.240 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.12.3 torch-2.9.1+cpu CPU (11th Gen Intel Core i7-11800H @ 2.30GHz)
# ...
